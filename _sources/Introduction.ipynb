# %% [markdown]
# # TUGAS 1 : Introduction

# %%
# Input nama pengguna
nama_pengguna = input("Halo! Siapa namamu? ")

# Perkenalan
print(f"Halo {nama_pengguna}! Senang bertemu denganmu.")
print("Apa kabar? Semoga harimu menyenangkan!")
# Out:
# Halo! Siapa namamu? misbachulmunir21003
# Halo misbachulmunir21003! Senang bertemu denganmu.
# Apa kabar? Semoga harimu menyenangkan!
